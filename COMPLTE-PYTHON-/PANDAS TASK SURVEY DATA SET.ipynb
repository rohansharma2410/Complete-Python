# %%
#SURVEY
#1 - Load the dataset into a pandas dataframe. Name the variable as “survey”. 
#2 - How many samples were collected on each day? 
#3 - What proportion of the total respondents were aged less than 45? 
#4 - Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+. The dataframe should look like this after the column creation. 
#5 - How many samples were collected for each age-group? Which age-group had the most samples? 
#6 - What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions? 
#7 - For each day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3. 
#8 - In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with their MLA. Create a line plot of the result with date on x-axis and proportions on the y-axis. 
#9 - Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the count of samples. Answer - survey.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'response_id', aggfunc = 'count') 
#10 - Repeat the above question with the cell values as the sum of “weight”. 
#11 - Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group. 
#12 - Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now. 
#13 - Join/Merge the two dataframes from questions 12 and 11 with the common column as age_group.

# %%
#upload csv file
import pandas as pd
survey=pd.read_csv(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\DSL data sets\9. Survey Dataset - Technical Interview.csv")

# %%
#SOLUTION 1 - Load the dataset into a pandas dataframe. Name the variable as “survey

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
#SOLUTION 2 - How many samples were collected on each day?

# %%
survey.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
survey.collection_date.unique()
# Out:
# array(['5-24-2017', '5-25-2017', '5-26-2017', '5-27-2017', '5-28-2017',
#        '5-29-2017', '5-30-2017', '5-31-2017', '6-1-2017'], dtype=object)

# %%
survey.groupby("collection_date").weight.sum()
# Out:
# collection_date
# 5-24-2017    1603.292440
# 5-25-2017     978.823365
# 5-26-2017     524.713123
# 5-27-2017     546.518462
# 5-28-2017     761.530009
# 5-29-2017     765.806120
# 5-30-2017     512.434387
# 5-31-2017     557.019170
# 6-1-2017      588.021526
# Name: weight, dtype: float64

# %%
#SURVEY 3 - What proportion of the total respondents were aged less than 45?

# %%
survey.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
survey.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                  object
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.replace({"24ko":24},inplace=True)

# %%
#To replace any(or missing) item of the series with a new value using dictionary format. 
#df.Col_name.replace( ) - df.Col.replace({1:‘one’ , ‘b’:‘bombay’, np.nan:s.mean( )}) }, inplace = True)
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', 24, '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
#df.Col_name.astype(int / float / str) 
survey["age"]=survey.age.astype(int)

# %%
survey.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                   int32
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
survey[survey.age<45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
len(survey[survey.age<45])
# Out:
# 6399

# %%
6867-6399
# Out:
# 468

# %%
6399/6867*100
# Out:
# 93.18479685452162

# %%
#SOLUTION 4 - Create a new column in the dataframe “age_group”. This column should contain the age group 
#the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+. The dataframe should look like this after 
#the column creation.

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
#df.insert( index , ‘new_column_name’, new_column_values) - To insert a New column at a particular position with values in it

# %%
survey.insert(11,"age_group",survey.age)

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
survey1=survey[(survey.age_group>18) & (survey.age_group<25)]

# %%
survey1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
survey1["age_group"]="18-25"
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13932\2943054417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey1["age_group"]="18-25"

# %%
survey2=survey[(survey.age_group>25) & (survey.age_group<40)]

# %%
survey2["age_group"]="25-40"
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13932\2585436635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey2["age_group"]="25-40"

# %%
survey3=survey[(survey.age_group>41) & (survey.age_group<55)]

# %%
survey3["age_group"]="41-55"
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13932\3110571471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey3["age_group"]="41-55"

# %%
survey4=survey[(survey.age_group>55) & (survey.age_group<100)]

# %%
survey4["age_group"]="55 plus"
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13932\1735748947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey4["age_group"]="55 plus"

# %%
survey1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
survey2
# Out:
#       response_id collection_date urban_rural          education  \
# 0               1       5-24-2017       Rural          12th Pass
# 1               2       5-24-2017       Rural           Graduate
# 3               4       5-24-2017       Urban           Graduate
# 5               6       5-24-2017       Urban           Graduate
# 6               7       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6852         6853        6-1-2017       Rural           Graduate
# 6854         6855        6-1-2017       Rural  Post - Graduation
# 6855         6856        6-1-2017       Rural          12th Pass
# 6863         6864        6-1-2017       Rural           Graduate
# 6866         6867        6-1-2017       Rural          10th Pass
#
#                    income   Vote_Now Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000        BJP       BJP  Fully Dissatisfied
# ...

# %%
survey3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6810         6811        6-1-2017       Rural          12th Pass
# 6812         6813        6-1-2017       Rural          10th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# ...

# %%
survey3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6810         6811        6-1-2017       Rural          12th Pass
# 6812         6813        6-1-2017       Rural          10th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# ...

# %%
survey4
# Out:
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 126           127       5-24-2017       Urban                Graduate
# 277           278       5-24-2017       Urban       Post - Graduation
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                      income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data=pd.concat([survey1,survey2,survey3,survey4])

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
#SURVEY 5 - How many samples were collected for each age-group? Which age-group had the most samples? #

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data.groupby("age_group").weight.sum()
# Out:
# age_group
# 18-25      1235.298994
# 25-40      2436.050849
# 41-55      2069.075845
# 55 plus     273.743870
# Name: weight, dtype: float64

# %%
#SURVEY 6-What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age gender  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22   Male
#
#   age_group  assembly_no category    weight
# 4     18-25          176       BC  0.333505

# %%
data.Vote_Now.unique()
# Out:
# array(['JD(U)', 'BJP', 'RJD', 'JAP(L)', 'Others', 'NOTA', 'BSP', 'RJJP',
#        'Plurals', 'AAP', 'INC', 'LJP', 'RLSP', 'HAM', 'Undecided', 'VIP',
#        'Left Front', 'AIMIM'], dtype=object)

# %%
data[(data.Vote_Now=="RJD") & (data.Past_Vote=="RJD")]
# Out:
#       response_id collection_date urban_rural          education  \
# 16             17       5-24-2017       Rural  Post - Graduation
# 38             39       5-24-2017       Urban           Graduate
# 47             48       5-24-2017       Urban           Graduate
# 85             86       5-24-2017       Rural          12th Pass
# 120           121       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 3012         3013       5-29-2017       Urban  Post - Graduation
# 4753         4754       5-26-2017       Rural  Post - Graduation
# 5493         5494       5-26-2017       Urban           Graduate
# 5687         5688       5-29-2017       Urban           Graduate
# 5830         5831       5-30-2017       Urban           Graduate
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# 16      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# ...

# %%
690/6867*100
# Out:
# 10.048055919615553

# %%
#SOLUTION 7 - For each day of sample collection, determine the proportion of respondents who were fully satisfied with the 
#performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, 
#then our answer for that day would be 0.3.

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age gender  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22   Male
#
#   age_group  assembly_no category    weight
# 4     18-25          176       BC  0.333505

# %%
data.CM_satisfaction.unique()
# Out:
# array(['Fully Satisfied', 'Fully Dissatisfied', 'Somewhat Dissatisfied',
#        'Can’t say', 'Somewhat Satisfied'], dtype=object)

# %%
cm=data[data.CM_satisfaction=="Fully Satisfied"]

# %%
cm
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 8               9       5-24-2017       Urban          12th Pass
# 14             15       5-24-2017       Rural           Graduate
# 90             91       5-24-2017       Rural           Graduate
# 102           103       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6498         6499       5-28-2017       Urban  Post - Graduation
# 6513         6514       5-28-2017       Urban  Post - Graduation
# 6787         6788        6-1-2017       Rural          10th Pass
# 6851         6852        6-1-2017       Urban           Graduate
#
#                      income Vote_Now     Past_Vote  CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote  Fully Satisfied
# ...

# %%
cm.collection_date.value_counts()
# Out:
# 5-24-2017    127
# 5-25-2017     82
# 5-28-2017     76
# 6-1-2017      65
# 5-29-2017     62
# 5-30-2017     60
# 5-31-2017     52
# 5-26-2017     47
# 5-27-2017     47
# Name: collection_date, dtype: int64

# %%
618/6867*100
# Out:
# 8.999563128003494

# %%
#SOLUTION 8 - In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with their MLA. 
#Create a line plot of the result with date on x-axis and proportions on the y-axis

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age gender  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22   Male
#
#   age_group  assembly_no category    weight
# 4     18-25          176       BC  0.333505

# %%
mla=data[data.MLA_satisfaction=="Fully Dissatisfied"]

# %%
mla
# Out:
#       response_id collection_date urban_rural               education  \
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 18             19       5-24-2017       Rural                Graduate
# 47             48       5-24-2017       Urban                Graduate
# 49             50       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6123         6124       5-24-2017       Urban  Professional Education
# 6262         6263       5-25-2017       Urban                Graduate
# 6268         6269       5-25-2017       Rural                Graduate
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
#
#                      income Vote_Now Past_Vote        CM_satisfaction  \
# ...

# %%
3554/6867*100
# Out:
# 51.75476918596185

# %%
mla.collection_date.value_counts()
# Out:
# 5-24-2017    774
# 5-25-2017    536
# 5-28-2017    397
# 6-1-2017     333
# 5-27-2017    331
# 5-30-2017    321
# 5-26-2017    299
# 5-29-2017    290
# 5-31-2017    273
# Name: collection_date, dtype: int64

# %%
#SOLUTION 9 - Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the
#count of samples. Answer - survey.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'response_id', aggfunc = 'count')

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age gender  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22   Male
#
#   age_group  assembly_no category    weight
# 4     18-25          176       BC  0.333505

# %%
#. df.pivot( index= ‘Col_1’ , columns= ‘Col_2’ , values=’Col_3’) ,
## It returns a reshaped DF organized by given index/columns values
data.pivot_table(index="Past_Vote",columns="Vote_Now", values="weight")
# Out:
# Vote_Now            AAP     AIMIM       BJP       BSP       HAM       INC  \
# Past_Vote
# BJP            0.442817  0.349996  0.655878  0.084617  2.034257  1.305315
# BSP                 NaN  1.654731  2.587244  7.579705       NaN  2.298223
# Did not vote   1.062923  1.075905  0.532785  1.664806  2.497170  1.277907
# HAM            0.156304       NaN  1.195855       NaN  1.648856       NaN
# INC                 NaN  1.899609  0.367168       NaN       NaN  2.919511
# JAP(L)              NaN       NaN  0.157624       NaN       NaN       NaN
# JD(U)          2.344061  2.752983  0.617065  0.178983  1.319787  2.131213
# LJP                 NaN       NaN  1.182203  2.481377       NaN  5.403346
# Left Front          NaN  2.298223  0.104793       NaN       NaN  2.291368
# NOTA                NaN  1.061204  0.425941  0.051485       NaN  0.427148
# Others        13.661335  4.979173  0.850017  0.684568  1.505864  0.347385
# ...

# %%
#SOLUTION 10 - Repeat the above question with the cell values as the sum of “weight”

# %%
data.pivot_table(index="Past_Vote",columns="Vote_Now", values="weight",aggfunc="sum")
# Out:
# Vote_Now            AAP      AIMIM         BJP        BSP        HAM  \
# Past_Vote
# BJP            2.214087   0.349996  925.443811   0.169233  10.171283
# BSP                 NaN   1.654731    5.174487  22.739115        NaN
# Did not vote   7.440458   5.379527  104.425845   3.329611   2.497170
# HAM            0.312607        NaN   23.917108        NaN   1.648856
# INC                 NaN   9.498047    1.468670        NaN        NaN
# JAP(L)              NaN        NaN    0.472873        NaN        NaN
# JD(U)         11.720303  24.776845  135.137236   0.178983   2.639574
# LJP                 NaN        NaN   80.389770   2.481377        NaN
# Left Front          NaN   2.298223    0.209586        NaN        NaN
# NOTA                NaN   1.061204   11.500407   0.051485        NaN
# Others        13.661335  19.916691   34.000662   0.684568   1.505864
# RJD            5.515847  22.938874   31.473132        NaN        NaN
# ...

# %%
#SOLUTION 11 - Create a dataframe by performing a group by over age_group and calculate the count of total 
#samples under each age_group.

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age gender  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22   Male
#
#   age_group  assembly_no category    weight
# 4     18-25          176       BC  0.333505

# %%
df1=data.groupby("age_group").count()

# %%
df1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             1969             1969         1969       1969    1969
# 25-40             3246             3246         3246       3246    3246
# 41-55              570              570          570        570     570
# 55 plus            108              108          108        108     108
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          1969       1969             1969              1969  1969
# 25-40          3246       3246             3246              3246  3246
# 41-55           570        570              570               570   570
# 55 plus         108        108              108               108   108
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        1969         1969      1969    1969
# 25-40        3246         3246      3246    3246
# 41-55         570          570       570     570
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
#SOLUTION 12 - Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group 
#that opted for the JD(U) party in Vote_Now.

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age gender  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22   Male
#
#   age_group  assembly_no category    weight
# 4     18-25          176       BC  0.333505

# %%
data.Vote_Now.unique()
# Out:
# array(['JD(U)', 'BJP', 'RJD', 'JAP(L)', 'Others', 'NOTA', 'BSP', 'RJJP',
#        'Plurals', 'AAP', 'INC', 'LJP', 'RLSP', 'HAM', 'Undecided', 'VIP',
#        'Left Front', 'AIMIM'], dtype=object)

# %%
jdu=data[data.Vote_Now=="JD(U)"]

# %%
jdu
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 67             68       5-24-2017       Urban          12th Pass
# 90             91       5-24-2017       Rural           Graduate
# 102           103       5-24-2017       Rural           Graduate
# 123           124       5-24-2017       Rural  Post - Graduation
# ...           ...             ...         ...                ...
# 1572         1573       5-25-2017       Urban  Post - Graduation
# 5248         5249       5-24-2017       Urban  Post - Graduation
# 5956         5957        6-1-2017       Urban          12th Pass
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6787         6788        6-1-2017       Rural          10th Pass
#
#                      income Vote_Now     Past_Vote     CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...

# %%
df2=jdu.groupby("age_group").count()

# %%
df2
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25              164              164          164        164     164
# 25-40              229              229          229        229     229
# 41-55               46               46           46         46      46
# 55 plus             10               10           10         10      10
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-25           164        164              164               164  164
# 25-40           229        229              229               229  229
# 41-55            46         46               46                46   46
# 55 plus          10         10               10                10   10
#
#            gender  assembly_no  category  weight
# age_group
# 18-25         164          164       164     164
# 25-40         229          229       229     229
# 41-55          46           46        46      46
# ...

# %%
#SOLUTION 13 - Join/Merge the two dataframes from questions 12 and 11 with the common column as age_group.

# %%
df1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             1969             1969         1969       1969    1969
# 25-40             3246             3246         3246       3246    3246
# 41-55              570              570          570        570     570
# 55 plus            108              108          108        108     108
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          1969       1969             1969              1969  1969
# 25-40          3246       3246             3246              3246  3246
# 41-55           570        570              570               570   570
# 55 plus         108        108              108               108   108
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        1969         1969      1969    1969
# 25-40        3246         3246      3246    3246
# 41-55         570          570       570     570
# ...

# %%
df2
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25              164              164          164        164     164
# 25-40              229              229          229        229     229
# 41-55               46               46           46         46      46
# 55 plus             10               10           10         10      10
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-25           164        164              164               164  164
# 25-40           229        229              229               229  229
# 41-55            46         46               46                46   46
# 55 plus          10         10               10                10   10
#
#            gender  assembly_no  category  weight
# age_group
# 18-25         164          164       164     164
# 25-40         229          229       229     229
# 41-55          46           46        46      46
# ...

# %%
#pd.merge( df1, df2, on=’Col_Name’ , how=’inner/outer/left/right’ )
# Merge ( ) - Column names must be same. Default – Inner Join
pd.merge(df1,df2, on="age_group", how="outer")
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-25               1969               1969           1969         1969
# 25-40               3246               3246           3246         3246
# 41-55                570                570            570          570
# 55 plus              108                108            108          108
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-25          1969        1969         1969               1969
# 25-40          3246        3246         3246               3246
# 41-55           570         570          570                570
# 55 plus         108         108          108                108
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-25                    1969   1969  ...       164         164          164
# ...

# %%
pd.merge(df1,df2, on="age_group", how="left")
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-25               1969               1969           1969         1969
# 25-40               3246               3246           3246         3246
# 41-55                570                570            570          570
# 55 plus              108                108            108          108
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-25          1969        1969         1969               1969
# 25-40          3246        3246         3246               3246
# 41-55           570         570          570                570
# 55 plus         108         108          108                108
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-25                    1969   1969  ...       164         164          164
# ...

# %%
pd.merge(df1,df2, on="age_group", how="right")
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-25               1969               1969           1969         1969
# 25-40               3246               3246           3246         3246
# 41-55                570                570            570          570
# 55 plus              108                108            108          108
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-25          1969        1969         1969               1969
# 25-40          3246        3246         3246               3246
# 41-55           570         570          570                570
# 55 plus         108         108          108                108
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-25                    1969   1969  ...       164         164          164
# ...

# %%
pd.merge(df1,df2, on="age_group")
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-25               1969               1969           1969         1969
# 25-40               3246               3246           3246         3246
# 41-55                570                570            570          570
# 55 plus              108                108            108          108
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-25          1969        1969         1969               1969
# 25-40          3246        3246         3246               3246
# 41-55           570         570          570                570
# 55 plus         108         108          108                108
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-25                    1969   1969  ...       164         164          164
# ...
