# %%
#NETFLIX
#Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records. Task. 2) Is there any Null Value present in any column ? Show with Heat-map. 
#Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?
#Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph. 
#Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph. 
#Q. 4) Show all the Movies that were released in year 2000. 
#Q. 5) Show only the Titles of all TV Shows that were released in India only. 
#Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ? 
#Q. 7) Shosw all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom". 
#Q. 8) In how many movies/shows, Tom Cruise was cast ? 
#Q. 9) What are the different Ratings defined by Netflix ? 
#Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ? 
#Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ? 
#Q. 10) What is the maximum duration of a Movie/Show on Netflix ? 
#Q. 11) Which individual country has the Highest No. of TV Shows ? 
#Q. 12) How can we sort the dataset by Year ? 
#Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
import pandas as pd

# %%
#upload csv file

# %%
netflix=pd.read_csv(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\DSL data sets\8. Netflix Dataset.csv")

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#SOLUTUON Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description
# 0  In a future where the elite inhabit an island ...

# %%
#df.duplicated( ) 
#It checks row wise and detects the duplicate rows.
netflix[netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
#It ignores duplicate rows.
# df.drop_duplicates( ) 
netflix.drop_duplicates(inplace=True )

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#SOLUTION Task. 2) Is there any Null Value present in any column ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description
# 0  In a future where the elite inhabit an island ...

# %%
#It detects the missing values from the dataframe.
#df.isnull( ) 
netflix.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#It detects the existing (non-missing) values from the dataframe.
netflix.notnull().sum()
# Out:
# Show_Id         7787
# Category        7787
# Title           7787
# Director        5399
# Cast            7069
# Country         7280
# Release_Date    7777
# Rating          7780
# Duration        7787
# Type            7787
# Description     7787
# dtype: int64

# %%
#SOLUTION  1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description
# 0  In a future where the elite inhabit an island ...

# %%
netflix[netflix.Title=="House of Cards"]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#SOLUTION 2) In which year the highest number of the TV Shows & Movies were released ?

# %%
netflix.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#to_datetime ( ) 
#Converts the data-type of Date-Time Column into datetime[ns] datatype
netflix["Release_Date"]=pd.to_datetime(netflix.Release_Date)

# %%
netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
#df[‘Year’] = df.Time_Col.dt.year. 
#Creating a new column with only year values.
netflix["year"]=netflix.Release_Date.dt.year

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0

# %%
netflix.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: year, dtype: int64

# %%
#SOLUTION 3) How many Movies & TV Shows are in the dataset ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0

# %%
netflix.Category.value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#SOLUTION 4)Show all the Movies that were released in year 2000

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0

# %%
netflix[netflix.year==2020]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 24       s25  TV Show      ​SAINT SEIYA: Knights of the Zodiac
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 0                 NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
len(netflix[netflix.year==2020])
# Out:
# 2009

# %%
#SOLUTION 5) Show only the Titles of all TV Shows that were released in India only

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0

# %%
netflix[(netflix.Category=="TV Show") & (netflix.Country=="India")]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country Release_Date  \
# ...

# %%
len(netflix[(netflix.Category=="TV Show") & (netflix.Country=="India")])
# Out:
# 71

# %%
#SOLUTION 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0

# %%
netflix.Director.value_counts()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Vibhu Virender Puri        1
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Sam Dunn                   1
# Name: Director, Length: 4050, dtype: int64

# %%
# SOLUTION 7) Shows all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
netflix[(netflix.Category=="Movie") & (netflix.Type=="Comedies") | (netflix.Country=="United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
len(netflix[(netflix.Category=="Movie") & (netflix.Type=="Comedies") | (netflix.Country=="United Kingdom")])
# Out:
# 485

# %%
#SOLUTION 8) In how many movies/shows, Tom Cruise was cast ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0

# %%
#df.Col_name.str.lower( ).str.contains(‘Value’)
netflix[netflix["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    year minutes unit
# 3860  Through chance, human action, past history and...  2020.0     189  min
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0     134  min

# %%
netflix.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# year              10
# dtype: int64

# %%
netflix.dropna(inplace=True)

# %%
netflix
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
netflix.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# year            0
# dtype: int64

# %%
netflix[netflix["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %%
#SOLUTION 9) What are the different Ratings defined by Netflix ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating Duration                          Type  \
# 1  TV-MA   93 min  Dramas, International Movies
#
#                                          Description    year
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
netflix.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#SOLUTION 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating Duration                          Type  \
# 1  TV-MA   93 min  Dramas, International Movies
#
#                                          Description    year
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
netflix[(netflix.Category=="Movie") & (netflix.Rating=="TV-14") & (netflix.Country=="Canada")]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %%
len(netflix[(netflix.Category=="Movie") & (netflix.Rating=="TV-14") & (netflix.Country=="Canada")])
# Out:
# 9

# %%
#SOLUTION 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating Duration                          Type  \
# 1  TV-MA   93 min  Dramas, International Movies
#
#                                          Description    year
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
netflix[(netflix.Category=="TV Shows") & (netflix.Rating=="R") & (netflix.year>2018)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %%
#SOLUTION 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating Duration                          Type  \
# 1  TV-MA   93 min  Dramas, International Movies
#
#                                          Description    year
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
netflix.Duration.unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
#df[[‘Col_1’, ‘Col_2’]] = df.Col_name.str.split(‘ ’, expand = True) 
## It splits a string into columns.
netflix[["minutes","unit"]]=netflix.Duration.str.split(" ", expand=True)

# %%
netflix
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
netflix.minutes.max()
# Out:
# '99'

# %%
#SOLUTION 11) Which individual country has the Highest No. of TV Shows ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating Duration                          Type  \
# 1  TV-MA   93 min  Dramas, International Movies
#
#                                          Description    year minutes unit
# 1  After a devastating earthquake hits Mexico Cit...  2016.0      93  min

# %%
#netflix_new=netflix[netflix["Category"]=="TV Show"]

# %%
#netflix_new.Country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %%
netflix[netflix["Category"]=="TV Show"].Country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %%
#SOLUTION 12) How can we sort the dataset by Year ?

# %%
netflix.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating Duration                          Type  \
# 1  TV-MA   93 min  Dramas, International Movies
#
#                                          Description    year minutes unit
# 1  After a devastating earthquake hits Mexico Cit...  2016.0      93  min

# %%
#df.sort_values(by=‘Col’, kind= ‘mergesort/quicksort/heapsort’)
netflix.sort_values(by="year",ascending=True)
# Out:
#      Show_Id Category                              Title  \
# 7115   s7114    Movie               To and From New York
# 5766   s5766    Movie                           Splatter
# 3248   s3249    Movie            Just Another Love Story
# 3840   s3841    Movie        Mad Ron's Prevues from Hell
# 3221   s3222    Movie             Joseph: King of Dreams
# ...      ...      ...                                ...
# 1426   s1427    Movie  Cloudy with a Chance of Meatballs
# 1739   s1740    Movie        Dhobi Ghat (Mumbai Diaries)
# 7553   s7552    Movie          What Happened to Mr. Cha?
# 2479   s2480    Movie                          Good Hair
# 3237   s3238    Movie                      Julie & Julia
#
#                            Director  \
# 7115           Sorin Dan Mihalcescu
# 5766                      Joe Dante
# 3248                   Ole Bornedal
# 3840                     Jim Monaco
# 3221  Rob LaDuca, Robert C. Ramirez
# ...                             ...
# ...

# %%
#SOLUTION 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'

# %%
netflix.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating Duration                          Type  \
# 1  TV-MA   93 min  Dramas, International Movies
#
#                                          Description    year minutes unit
# 1  After a devastating earthquake hits Mexico Cit...  2016.0      93  min

# %%
netflix[(netflix.Category=="Movie") & (netflix.Type=="Dramas") | (netflix.Category=="TV Show") & (netflix.Type=="Kids' TV")]
# Out:
#      Show_Id Category                       Title          Director  \
# 4         s5    Movie                          21    Robert Luketic
# 7         s8    Movie                         187    Kevin Reynolds
# 170     s171    Movie                A Family Man     Mark Williams
# 232     s233    Movie  A Stoning in Fulham County     Larry Elikann
# 276     s277  TV Show                Abby Hatcher       Kyran Kelly
# ...      ...      ...                         ...               ...
# 7422   s7421    Movie                     Villain  Philip Barantini
# 7449   s7448    Movie                         VS.          Ed Lilly
# 7465   s7464    Movie                   Wakefield     Robin Swicord
# 7480   s7479    Movie                   War Horse  Steven Spielberg
# 7668   s7667  TV Show               World of Winx    Iginio Straffi
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
