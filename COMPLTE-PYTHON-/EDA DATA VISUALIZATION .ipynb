# %% [markdown]
# DATA VISUALIZATION LIBRARY
# MATPLOTLIB: Helps in EDA: Helps us in identifying Trends in data
#
# Other Libraries that we will discuss are: Plotly and Seaborn
#
# For Dashboarding purposes, PowerBI and Tableau is widely used but for basic EDA, we use these above libraries
#
# Line Plot, Bar Plot, 3D Plot, Histogram, Scatter Plot etc.

# %%
#pip install cufflinks
# !pip install cufflinks

# %%
import cufflinks as cf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cf.go_offline #Since we are using offline mode

# %%
df=sns.load_dataset('iris')#seabron library has datasets
df
#loading a sns data,it's available in sns
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# by default it will plot line graph
#it will pot only numerical columns
# x axis = row indexes
# y axis = all the values of columns individually
# without using df.describe() ,still we can say something about data
# we can say the variance also ,like which has more variance
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind ='area',alpha = 0.4)
# kind is parameter of which type of plot I want(jus shift tab u will see diffrent types of availability of graphs)
# alpha mention density of the colour
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="hist", alpha=0.4)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind ='area',alpha = 0.6,stacked = False)
# stack means I want plot the data with normal scale
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ='hist',alpha = 0.9,stacked = False)
# stack means I want plot the data with normal scale
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x = 'sepal_length',y = 'sepal_width')
# it is going to take the scale on the basis of the data like min and max of the data
# there is no relation
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x = 'sepal_length',y = 'petal_length')
# here we can made the decision that if sepa_ength is increasing then petal_ength is also increasing
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length',y = 'petal_length',c = "sepal_width")
# the meaning of c is colour  I give colour of the dot,by the corresponding point in the colourwe have to go and decide
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x = 'sepal_length',y = 'petal_length',c = "sepal_width",s = 10)
# s is fixed the size for the dot
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length',y = 'petal_length',c = "sepal_width",s = 1000)
# s is fixed the size for the dot
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length',y = 'petal_length',c = "petal_length",s = 10)
# s is fixed the size for the dot
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length',y = 'petal_length',c = "petal_length",s = df['sepal_length']*20)
# s is fixed the size for the plot
# we can give s like any way we want
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length',y = 'petal_length',gridsize = 10)
# for hexbin we have to give gridsize instead of s
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length',y = 'petal_length',gridsize = 10,cmap = "viridis")
# for hexbin we have to give gridsize instead of s
# cmap for colourmap for creating a fancy graph
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d
# for plotting 3D graph
# without this we can't plot any 3D graph

# %%
x= np.linspace(-1,6 , 30)
x
# it will generate 30 data in data range of -1 to 6
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1,6 ,30)
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z =x+y
# we need must z for 3d graph

# %%
z
# Out:
# array([-2.        , -1.51724138, -1.03448276, -0.55172414, -0.06896552,
#         0.4137931 ,  0.89655172,  1.37931034,  1.86206897,  2.34482759,
#         2.82758621,  3.31034483,  3.79310345,  4.27586207,  4.75862069,
#         5.24137931,  5.72413793,  6.20689655,  6.68965517,  7.17241379,
#         7.65517241,  8.13793103,  8.62068966,  9.10344828,  9.5862069 ,
#        10.06896552, 10.55172414, 11.03448276, 11.51724138, 12.        ])

# %%
ax = plt.axes(projection = "3d") #white colour box is created by (projection = "3d")
ax.plot3D(x,y,z)
ax.set_xlabel('x')  # # for setting the label of x
ax.set_ylabel('y')  # for setting the label of y
ax.set_zlabel('z')  # for setting the label of z
# LINEAR RELATION WE HAVE
# Out:
# Text(0.5, 0, 'z')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax = plt.axes(projection = "3d") #white colour box iscreated by (projection = "3d")  #plt is alias 
ax.plot3D(df["sepal_length"],df["sepal_width"], df['petal_length'])
ax.set_xlabel("sepal_length")  # # for setting the label of x
ax.set_ylabel("sepal_width")  # for setting the label of y
ax.set_zlabel('petal_length')  # for setting the label of z
# Out:
# Text(0.5, 0, 'petal_length')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10))
# fixing the figsize
# Out:
# <AxesSubplot:>

# %% [markdown]
# BARGRAPH

# %%
df.plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ="bar",figsize=(20,10))
# fixing the size
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind ="bar",figsize=(20,10))
#iloc helps us to select a specific row or column from the data set
# we can experiment so many things basis on my procedure
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind ="barh",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# HISTOGRAM

# %%
df.plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind = "hist",figsize =(20,10))
# it will help to understand the range and frequencies
# x is for range and y axis for frequeny(how many counts or datapoints we have)
# its like groupby operation
# we can say range and we can say the frequency as well
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind = "hist",figsize=(20,10))
# for one particular column
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize = (20,10),color = 'g',alpha = .9)
# aplha for coloue density
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10),color = '#EDC126',alpha = .9)
# aplha for coloue density
# WE CAN GO LEARN CODE ONLINE FOR THE COLOUR
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# this graph will be interactive 
# without cufflinks we can't df.iplot()
# iplot is from ploty and cufflinks
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="2015d257-be06-42d5-8e1a-2bd64ee85387" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(x ="sepal_length",y = "sepal_width",kind = "scatter" )
# scatter plot
# Out:
# <div>                            <div id="c63f21b6-8651-424a-a87f-077df4658e7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x ="sepal_length",y = "sepal_width",kind = "scatter" ,mode = "markers")
# it's changed for mode
# Out:
# <div>                            <div id="f99f7478-c176-4372-a900-730c2f565aa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x ="sepal_length",y = "sepal_width",kind = "bubble" ,size ="petal_length",mode = "markers")
# bubble plot
# Out:
# <div>                            <div id="947b0f87-90c3-4444-b6f1-69531826cfa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x ="sepal_length",y = "sepal_width",kind = "bubble3d",z="petal_length" ,size ="petal_length")
# bubble plot
# Out:
# <div>                            <div id="3689fc59-109b-425f-8cdb-fb453357b465" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')
# tips dataset

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(x ='total_bill' , y ='tip' ,kind = "scatter")
# if bill is high then tip is also
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x ='total_bill' , y ='tip' ,kind = "scatter",mode = "markers")
# if bill is high then tip is also
# we have to use mode = "markers"
# Out:
# <div>                            <div id="6edf3f14-bc6e-408b-ae79-167640d065ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# SEABORN

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1["smoker"].value_counts()
#  value_counts() like groupby
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,hue = 'smoker')
# smoker person gives the highest tips

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,hue = 'time')
# who gave the highest tip is coming for dinner

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,hue = 'time',style = "smoker")
# style gives me the more information

# %% [markdown]
# HUE AND STYLE IS USING FOR GROUP OPERATION

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,hue = 'time',style = "sex")
# The person is gave the highest tip was a male

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,hue = 'sex')
# The person is gave the highest tip was a male

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,hue = 'size',style = "size")

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,col= "time")
# majority of people are coming for dinner

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x ='sepal_length' , y ='sepal_width',data = df,col ="species")
#

# %%
sns.relplot(x ='total_bill' , y ='tip',data = df1,col= "day")
# majority of people are coming on saturday and sunday

# %%
df1['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.catplot(x = "day", y = "total_bill" ,data = df1)
# for categorical data
# on saturday we get highest bill

# %%
sns.pairplot(data = df1)
# on a diagonal we have to see histogram 
# actually its one vs another

# %%
sns.pairplot(df)

# %% [markdown]
# IN PLOTLY

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="c335e0dc-5973-4dfa-83ed-2a72f3560627" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# FEW CODE FROM OFFICIAL DOCUMENTATION WEBSITE

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(df['sepal_length'], bins=9, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (0.75, 1.00, 0.75), (200, 3))

# plot:
fig, ax = plt.subplots()

vp = ax.violinplot(D, [2, 4, 6], widths=2,
                   showmeans=False, showmedians=False, showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.9)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x =df1.total_bill , y = df1.tip )

# %%
sns.jointplot(x =df1.total_bill , y = df1.tip,kind = 'hex' )

# %%
sns.jointplot(x = df1.total_bill,y =df1.tip , kind = "hex" )

# %%
sns.pairplot(df1)
# diagonal will be histogram rest of all is one vs another

# %%
sns.regplot(x = df1.total_bill , y = df1.tip)
# regression plot
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x = df1.total_bill , y = df1.tip)
sns.set(rc={'figure.figsize':(20,10)})
# setting the figure sixe

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid") # for theme you can change from official documentation

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15)) # f for figure , ax for axis

# Load the example car crash dataset
df1 = sns.load_dataset("tips").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total_bill", y="tip", data=df1,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20624\2226053507.py in <module>
#       7
#       8 # Load the example car crash dataset
# ----> 9 df1 = sns.load_dataset("tips").sort_values("total", ascending=False)
#      10
#      11 # Plot the total crashes
#
# ~\a\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\a\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6320
#    6321             by = by[0]
# -> 6322             k = self._get_label_or_level_values(by, axis=axis)
#    6323
# ...

# %%
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)
crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 17   21.4     4.066    4.922          16.692       16.264       872.51
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
# 36   19.9     6.368    5.771          18.308       18.706       881.51
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)      # for notation
ax.set(xlim=(0, 24), ylabel="",xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
# x and y given as array_like objects
import plotly.express as px
fig = px.scatter(df1,x = 'total_bill' , y = "tip", color = "time")   # based on time it takes color
fig.show()
# Out:
# <div>                            <div id="a6149b94-7ed0-46ed-9b97-45aae1455673" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6149b94-7ed0-46ed-9b97-45aae1455673")) {                    Plotly.newPlot(                        "a6149b94-7ed0-46ed-9b97-45aae1455673",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %%
import plotly.express as px

fig = px.scatter(df1, x="total_bill", y="tip", color="time")
fig.show()
# Out:
# <div>                            <div id="24907947-0520-4026-958b-a2f00674e346" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24907947-0520-4026-958b-a2f00674e346")) {                    Plotly.newPlot(                        "24907947-0520-4026-958b-a2f00674e346",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %%
import plotly.express as px

fig = px.bar(df1, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()
# Out:
# <div>                            <div id="f7deb9a3-7c8a-4591-af33-b6d8462f5284" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7deb9a3-7c8a-4591-af33-b6d8462f5284")) {                    Plotly.newPlot(                        "f7deb9a3-7c8a-4591-af33-b6d8462f5284",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...

# %% [markdown]
# cufflinks - https://github.com/santosjorge/cufflinks
# plotly - https://plotly.com/python/plotly-express/
# seaborn - https://seaborn.pydata.org/index.html
# matplotlib - https://matplotlib.org/stable/index.html
