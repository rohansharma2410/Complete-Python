# %%
import pandas as pd

# %%
#import excel file
sample=pd.read_excel(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\DSL data sets\10.-Sample.xlsx")

# %%
sample
# Out:
#       Order Date     Customer Name    Segment             City       State  \
# 0      11/8/2016       Claire Gute   Consumer        Henderson    Kentucky
# 1      11/8/2016       Claire Gute   Consumer        Henderson    Kentucky
# 2      6/12/2016   Darrin Van Huff  Corporate      Los Angeles  California
# 3     10/11/2015    Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4     10/11/2015    Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# ...          ...               ...        ...              ...         ...
# 9989   1/21/2014  Tom Boeckenhauer   Consumer            Miami     Florida
# 9990   2/26/2017       Dave Brooks   Consumer       Costa Mesa  California
# 9991   2/26/2017       Dave Brooks   Consumer       Costa Mesa  California
# 9992   2/26/2017       Dave Brooks   Consumer       Costa Mesa  California
# 9993    5/4/2017      Chris Cortes   Consumer      Westminster  California
#
# ...

# %%
sample.columns
# Out:
# Index(['Order Date', 'Customer Name', 'Segment', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales',
#        'Quantity', 'Profit'],
#       dtype='object')

# %%
sample.head(1)
# Out:
#   Order Date Customer Name   Segment       City     State  Postal Code Region  \
# 0  11/8/2016   Claire Gute  Consumer  Henderson  Kentucky        42420  South
#
#     Category Sub-Category   Sales  Quantity   Profit
# 0  Furniture    Bookcases  261.96         2  41.9136

# %%
pd.pivot_table
# Out:
# <function pandas.core.reshape.pivot.pivot_table(data: 'DataFrame', values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins: 'bool' = False, dropna: 'bool' = True, margins_name: 'str' = 'All', observed: 'bool' = False, sort: 'bool' = True) -> 'DataFrame'>

# %%
pd.pivot_table(data=sample, index=["State"])
# Out:
#                        Postal Code      Profit  Quantity        Sales
# State
# Alabama               35994.573770   94.865989  4.196721   319.846557
# Arizona               85277.348214  -15.303235  3.848214   157.508933
# Arkansas              72321.816667   66.811452  4.000000   194.635500
# California            92145.246877   38.171608  3.831584   228.729451
# Colorado              80295.758242  -35.867351  3.807692   176.418231
# Connecticut            6475.670732   42.823071  3.426829   163.223866
# Delaware              19755.250000  103.930988  3.822917   285.948635
# District of Columbia  20016.000000  105.958930  4.000000   286.502000
# Florida               33003.198433   -8.875461  3.600522   233.612815
# Georgia               30899.347826   88.315453  3.831522   266.825217
# Idaho                 83462.333333   39.367767  3.047619   208.689810
# Illinois              60719.048780  -25.625787  3.750000   162.939230
# ...

# %%
pd.pivot_table(data=sample, index=["State","State","Region"])
# Out:
#                                                     Postal Code      Profit  \
# State                State                Region
# Alabama              Alabama              South    35994.573770   94.865989
# Arizona              Arizona              West     85277.348214  -15.303235
# Arkansas             Arkansas             South    72321.816667   66.811452
# California           California           West     92145.246877   38.171608
# Colorado             Colorado             West     80295.758242  -35.867351
# Connecticut          Connecticut          East      6475.670732   42.823071
# Delaware             Delaware             East     19755.250000  103.930988
# District of Columbia District of Columbia East     20016.000000  105.958930
# Florida              Florida              South    33003.198433   -8.875461
# Georgia              Georgia              South    30899.347826   88.315453
# Idaho                Idaho                West     83462.333333   39.367767
# ...

# %%
sample.head(1)
# Out:
#   Order Date Customer Name   Segment       City     State  Postal Code Region  \
# 0  11/8/2016   Claire Gute  Consumer  Henderson  Kentucky        42420  South
#
#     Category Sub-Category   Sales  Quantity   Profit
# 0  Furniture    Bookcases  261.96         2  41.9136

# %%
pd.pivot_table(data=sample, index=["State"],values="Sales")
# Out:
#                             Sales
# State
# Alabama                319.846557
# Arizona                157.508933
# Arkansas               194.635500
# California             228.729451
# Colorado               176.418231
# Connecticut            163.223866
# Delaware               285.948635
# District of Columbia   286.502000
# Florida                233.612815
# Georgia                266.825217
# Idaho                  208.689810
# Illinois               162.939230
# Indiana                359.431946
# Iowa                   152.658667
# Kansas                 121.429583
# Kentucky               263.250000
# Louisiana              219.453095
# Maine                  158.816250
# Maryland               225.766886
# Massachusetts          212.106919
# Michigan               299.096525
# Minnesota              335.541011
# Mississippi            203.232830
# Missouri               336.441667
# Montana                372.623467
# Nebraska               196.445526
# ...

# %%
pd.pivot_table(data=sample,index=["State", "City","Region"],values=['Sales','Profit'] )
# Out:
#                                   Profit        Sales
# State     City       Region
# Alabama   Auburn     South     75.434517   294.471667
#           Decatur    South     76.929854   259.601538
#           Florence   South     49.731780   399.470000
#           Hoover     South      4.679325   131.462500
#           Huntsville South    100.525720   248.437000
# ...                                  ...          ...
# Wisconsin Superior   Central   57.120244   144.414444
#           Waukesha   Central   14.170000    54.500000
#           Wausau     Central   22.607650    79.370000
#           West Allis Central   14.185400   125.240000
# Wyoming   Cheyenne   West     100.196000  1603.136000
#
# [604 rows x 2 columns]

# %%
#by default valjues calculates average 
pd.pivot_table(data=sample,index=["State", "City","Region"],values=['Sales','Profit'])
# Out:
#                                   Profit        Sales
# State     City       Region
# Alabama   Auburn     South     75.434517   294.471667
#           Decatur    South     76.929854   259.601538
#           Florence   South     49.731780   399.470000
#           Hoover     South      4.679325   131.462500
#           Huntsville South    100.525720   248.437000
# ...                                  ...          ...
# Wisconsin Superior   Central   57.120244   144.414444
#           Waukesha   Central   14.170000    54.500000
#           Wausau     Central   22.607650    79.370000
#           West Allis Central   14.185400   125.240000
# Wyoming   Cheyenne   West     100.196000  1603.136000
#
# [604 rows x 2 columns]

# %%
pd.pivot_table(data=sample,index=["State", "City","Region"],values=['Sales','Profit'],aggfunc=sum)
# Out:
#                                  Profit     Sales
# State     City       Region
# Alabama   Auburn     South     452.6071  1766.830
#           Decatur    South    1000.0881  3374.820
#           Florence   South     248.6589  1997.350
#           Hoover     South      18.7173   525.850
#           Huntsville South    1005.2572  2484.370
# ...                                 ...       ...
# Wisconsin Superior   Central   514.0822  1299.730
#           Waukesha   Central    14.1700    54.500
#           Wausau     Central    90.4306   317.480
#           West Allis Central    28.3708   250.480
# Wyoming   Cheyenne   West      100.1960  1603.136
#
# [604 rows x 2 columns]

# %%
pd.pivot_table(data=sample,index=['Segment', 'State'],values=['Sales','Profit'], aggfunc=[sum,len])
# Out:
#                                   sum                len
#                                Profit       Sales Profit Sales
# Segment     State
# Consumer    Alabama         1711.0939    7537.540     25    25
#             Arizona        -1423.0527   16424.422    110   110
#             Arkansas        3152.8321    8802.010     37    37
#             California     38374.0392  229636.080   1048  1048
#             Colorado       -1614.5502   15794.492     95    95
# ...                               ...         ...    ...   ...
# Home Office Virginia        1762.6102    7451.610     45    45
#             Washington      4289.4352   25047.640    100   100
#             West Virginia    262.8752     536.480      3     3
#             Wisconsin       1529.7229    5486.620     28    28
#             Wyoming          100.1960    1603.136      1     1
#
# [140 rows x 4 columns]

# %%
sample.head(1)
# Out:
#   Order Date Customer Name   Segment       City     State  Postal Code Region  \
# 0  11/8/2016   Claire Gute  Consumer  Henderson  Kentucky        42420  South
#
#     Category Sub-Category   Sales  Quantity   Profit
# 0  Furniture    Bookcases  261.96         2  41.9136

# %%
pd.pivot_table(data=sample, index=['Category'],values=['Sales','Profit'],columns=['Customer Name'],aggfunc=sum)
# Out:
#                     Profit                                             \
# Customer Name        False Aaron Bergman Aaron Hawkins Aaron Smayling
# Category
# Furniture        1050.4888       60.1937       58.9972        77.8707
# Office Supplies   121.5746        6.9984      219.5759       -39.6206
# Technology       1477.3371       62.1544       86.6421      -291.8247
#
#                                                                             \
# Customer Name   Adam Bellavance Adam Hart Adam Shillingsburg Adrian Barton
# Category
# Furniture              334.5016  -40.7154           291.9630      -75.2050
# Office Supplies       1656.2939  328.1144          -261.6142     5353.2848
# Technology              63.7930   -6.2100            34.1886      166.7257
#
#                                           ...          Sales              \
# Customer Name   Adrian Hane Adrian Shami  ... Vivek Gonzalez Vivek Grady
# Category                                  ...
# ...

# %%
pd.pivot_table(data=sample,index=["State"],values=["Sales"],columns=["Category"],aggfunc=sum)
# Out:
#                             Sales
# Category                Furniture Office Supplies  Technology
# State
# Alabama                 6332.4800        4209.080    8969.080
# Arizona                13525.2910       10005.825   11750.885
# Arkansas                3187.5500        4565.330    3925.250
# California            156064.6015      142351.948  159271.082
# Colorado               13243.0370        7898.752   10966.329
# Connecticut             5174.9870        5418.340    2791.030
# Delaware                4759.3190        8129.530   14562.220
# District of Columbia    1346.5800         138.520    1379.920
# Florida                22987.0380       19518.634   46968.036
# Georgia                 8321.4800       26715.810   14058.550
# Idaho                   2595.4820         949.506     837.498
# Illinois               28274.5220       19907.906   31983.673
# Indiana                11496.7100       15735.400   26323.250
# ...

# %%
pd.pivot_table(data=sample,index=["State"],values=["Sales"],columns=["Category"],aggfunc=len)
# Out:
#                          Sales
# Category             Furniture Office Supplies Technology
# State
# Alabama                   11.0            36.0       14.0
# Arizona                   49.0           127.0       48.0
# Arkansas                   9.0            36.0       15.0
# California               444.0          1198.0      359.0
# Colorado                  51.0            96.0       35.0
# Connecticut               13.0            58.0       11.0
# Delaware                  18.0            58.0       20.0
# District of Columbia       3.0             6.0        1.0
# Florida                   85.0           229.0       69.0
# Georgia                   32.0           115.0       37.0
# Idaho                      6.0            11.0        4.0
# Illinois                 123.0           285.0       84.0
# Indiana                   23.0            97.0       29.0
# Iowa                       4.0            22.0        4.0
# ...

# %%
pd.pivot_table(data=sample,index=["State"],values=["Sales","Profit"],columns=["Category"],aggfunc=[sum,len])
# Out:
#                              sum                                           \
#                           Profit                                    Sales
# Category               Furniture Office Supplies  Technology    Furniture
# State
# Alabama                1231.3882       1257.6342   3297.8029    6332.4800
# Arizona               -2744.9228       -795.5030    112.5012   13525.2910
# Arkansas                781.4552       1965.7935   1261.4384    3187.5500
# California             9162.9656      37748.3847  29470.0368  156064.6015
# Colorado              -2683.1342       -373.1392  -3471.5845   13243.0370
# Connecticut            1226.2805       1504.2777    780.9336    5174.9870
# Delaware                870.7072       2867.6168   6239.0508    4759.3190
# District of Columbia    350.0835         60.9434    648.5624    1346.5800
# Florida               -2254.9807      -1675.1258    530.8048   22987.0380
# Georgia                2049.4580       9800.9256   4399.6597    8321.4800
# ...

# %%
sample.isnull().sum()
# Out:
# Order Date       0
# Customer Name    0
# Segment          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Category         0
# Sub-Category     0
# Sales            0
# Quantity         0
# Profit           0
# dtype: int64

# %%
sample.notnull().sum()
# Out:
# Order Date       9994
# Customer Name    9994
# Segment          9994
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Category         9994
# Sub-Category     9994
# Sales            9994
# Quantity         9994
# Profit           9994
# dtype: int64

# %%
pd.pivot_table(sample, index=["Category"],values=["Sales","Profit"],columns=["Customer Name"],aggfunc=sum, fill_value=0)
# Out:
#                     Profit                                             \
# Customer Name        False Aaron Bergman Aaron Hawkins Aaron Smayling
# Category
# Furniture        1050.4888       60.1937       58.9972        77.8707
# Office Supplies   121.5746        6.9984      219.5759       -39.6206
# Technology       1477.3371       62.1544       86.6421      -291.8247
#
#                                                                             \
# Customer Name   Adam Bellavance Adam Hart Adam Shillingsburg Adrian Barton
# Category
# Furniture              334.5016  -40.7154           291.9630      -75.2050
# Office Supplies       1656.2939  328.1144          -261.6142     5353.2848
# Technology              63.7930   -6.2100            34.1886      166.7257
#
#                                           ...          Sales              \
# Customer Name   Adrian Hane Adrian Shami  ... Vivek Gonzalez Vivek Grady
# Category                                  ...
# ...

# %%
pd.pivot_table(sample, index=["Category"],values=["Sales","Profit"],columns=["Customer Name"],aggfunc=sum, 
               fill_value=0,margins="True",margins_name="Total")
# Out:
#                     Profit                                             \
# Customer Name        False Aaron Bergman Aaron Hawkins Aaron Smayling
# Category
# Furniture        1050.4888       60.1937       58.9972        77.8707
# Office Supplies   121.5746        6.9984      219.5759       -39.6206
# Technology       1477.3371       62.1544       86.6421      -291.8247
# Total            2649.4005      129.3465      365.2152      -253.5746
#
#                                                                             \
# Customer Name   Adam Bellavance Adam Hart Adam Shillingsburg Adrian Barton
# Category
# Furniture              334.5016  -40.7154           291.9630      -75.2050
# Office Supplies       1656.2939  328.1144          -261.6142     5353.2848
# Technology              63.7930   -6.2100            34.1886      166.7257
# Total                 2054.5885  281.1890            64.5374     5444.8055
#
# ...

# %%
sample.head(1)
# Out:
#   Order Date Customer Name   Segment       City     State  Postal Code Region  \
# 0  11/8/2016   Claire Gute  Consumer  Henderson  Kentucky        42420  South
#
#     Category Sub-Category   Sales  Quantity   Profit
# 0  Furniture    Bookcases  261.96         2  41.9136

# %%
pd.pivot_table(data=sample,index=["State","City"],columns=["Segment"],values=["Sales","Profit"],
          margins=True, margins_name="Total",aggfunc=sum,fill_value=0)
# Out:
#                            Profit                                       \
# Segment                  Consumer   Corporate Home Office        Total
# State     City
# Alabama   Auburn         451.5167      0.0000      1.0904     452.6071
#           Decatur         77.4454    922.6427      0.0000    1000.0881
#           Florence       246.2187      0.0000      2.4402     248.6589
#           Hoover           0.0000     18.7173      0.0000      18.7173
#           Huntsville      27.0572    605.3942    372.8058    1005.2572
# ...                           ...         ...         ...          ...
# Wisconsin Waukesha        14.1700      0.0000      0.0000      14.1700
#           Wausau          90.4306      0.0000      0.0000      90.4306
#           West Allis       0.0000     28.3708      0.0000      28.3708
# Wyoming   Cheyenne         0.0000      0.0000    100.1960     100.1960
# Total                 134119.2092  91979.1340  60298.6785  286397.0217
#
# ...

# %%
pd.pivot_table(data=sample,index=["State","City"],columns=['Segment'],values=['Sales','Profit'],
          margins=True, margins_name="Total",aggfunc={'Sales':sum,'Profit':average},fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19976\2169108942.py in <module>
#       1 pd.pivot_table(data=sample,index=["State","City"],columns=['Segment'],values=['Sales','Profit'],
# ----> 2           margins=True, margins_name="Total",aggfunc={'Sales':sum,'Profit':average},fill_value=0)
#
# NameError: name 'average' is not defined

# %%
pd.pivot_table(data=sample,index=["State","City"],columns=['Segment'],values=['Sales','Profit'],
          margins=True, margins_name="Total",aggfunc={'Sales':sum,'Profit':mean},fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19976\3828389714.py in <module>
#       1 pd.pivot_table(data=sample,index=["State","City"],columns=['Segment'],values=['Sales','Profit'],
# ----> 2           margins=True, margins_name="Total",aggfunc={'Sales':sum,'Profit':mean},fill_value=0)
#
# NameError: name 'mean' is not defined

# %%
import numpy as np

# %%
pd.pivot_table(data=sample,index=["State","City"],columns=['Segment'],values=['Sales','Profit'],
          margins=True, margins_name="Total",aggfunc={'Sales':sum,'Profit':np.average},fill_value=0)
# Out:
#                          Profit                                      \
# Segment                Consumer   Corporate Home Office       Total
# State     City
# Alabama   Auburn      90.303340    0.000000    1.090400   75.434517
#           Decatur     19.361350  102.515856    0.000000   76.929854
#           Florence    61.554675    0.000000    2.440200   49.731780
#           Hoover       0.000000    4.679325    0.000000    4.679325
#           Huntsville  13.528600  151.348550   93.201450  100.525720
# ...                         ...         ...         ...         ...
# Wisconsin Waukesha    14.170000    0.000000    0.000000   14.170000
#           Wausau      22.607650    0.000000    0.000000   22.607650
#           West Allis   0.000000   14.185400    0.000000   14.185400
# Wyoming   Cheyenne     0.000000    0.000000  100.196000  100.196000
# Total                 25.836873   30.456667   33.818664   28.656896
#
#                             Sales
# ...

# %%
pd.pivot_table(data=sample,index=['State','Customer Name'],columns=['Segment'],values=['Sales','Profit'],
          margins=True, margins_name="Total",aggfunc={'Sales':[np.sum,np.average],'Profit':np.average},fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19976\4076510003.py in <module>
# ----> 1 pd.pivot_table(data=sample,index=['State','Customer Name'],columns=['Segment'],values=['Sales','Profit'],
#       2           margins=True, margins_name="Total",aggfunc={'Sales':[np.sum,np.average],'Profit':np.average},fill_value=0)
#
# ~\a\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ---> 95     table = __internal_pivot_table(
#      96         data,
#      97         values,
#
# ...

# %%
pd.pivot_table(data=sample,index=['State','Customer Name'],columns=['Segment'],values=['Sales','Profit'],
          aggfunc={'Sales':[np.sum,np.average],'Profit':np.average})
# Out:
#                                 Profit                            Sales  \
#                                average                          average
# Segment                       Consumer   Corporate Home Office Consumer
# State     Customer Name
# Alabama   Alan Schoenberger        NaN  148.230067         NaN      NaN
#           Amy Hunt            6.872400         NaN         NaN   14.940
#           Anne McFarland     69.087467         NaN         NaN  421.380
#           Anne Pryor               NaN         NaN      2.4402      NaN
#           Bart Folk           3.960900         NaN         NaN   14.670
# ...                                ...         ...         ...      ...
# Wisconsin Steve Chapman            NaN   60.916525         NaN      NaN
#           Theresa Swint            NaN   14.185400         NaN      NaN
#           Troy Blackwell     60.356000         NaN         NaN  754.450
#           Trudy Schmidt      46.221000         NaN         NaN  165.075
# ...

# %%
pd.pivot_table(data=sample,index=['State','Customer Name'],columns=['Segment'],values=['Sales','Profit'],
               margins_name="Total",aggfunc={'Sales':[np.sum,np.average],'Profit':np.average})
# Out:
#                                 Profit                            Sales  \
#                                average                          average
# Segment                       Consumer   Corporate Home Office Consumer
# State     Customer Name
# Alabama   Alan Schoenberger        NaN  148.230067         NaN      NaN
#           Amy Hunt            6.872400         NaN         NaN   14.940
#           Anne McFarland     69.087467         NaN         NaN  421.380
#           Anne Pryor               NaN         NaN      2.4402      NaN
#           Bart Folk           3.960900         NaN         NaN   14.670
# ...                                ...         ...         ...      ...
# Wisconsin Steve Chapman            NaN   60.916525         NaN      NaN
#           Theresa Swint            NaN   14.185400         NaN      NaN
#           Troy Blackwell     60.356000         NaN         NaN  754.450
#           Trudy Schmidt      46.221000         NaN         NaN  165.075
# ...
