# %%
#SUPERSTORE DATA SET 
#1 . load this data in sql and in pandas with a relation in sql 
#2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
#3 . Find out how return that we ahve recived and with a product id 
#4 . try  to join order and return data both in sql and pandas 
#5 . Try to find out how many unique customer that we have 
#6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
#7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
#8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
#9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
#10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
#11 . Gorup by region and find out which region is more profitable 
#12 . Try to find out overalll in which country we are giving more didscount 
#13 . Give me a list of unique postal code 
#14 . which customer segement is more profitalble find it out . 
#15 . try to find out the 10th most loss making product catagory . 
#16 . Try to find out 10 top  product with highest margins

# %%
import pandas as pd

# %%
#SOLUTION 1
#to upload excel file in pandas
superstore=pd.read_excel(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\INeuron_pandas data sets\Superstore_USA.xlsx")

# %%
superstore
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#First to load excel file directly into database .followthe steps.
#step 1 : Right click on table 
#step 2 : Select "Table Data Import Wizard"
#step 3 : Select the file which we have to load (in our case, it is superstore_data.csv) and press next.
#step 4 : Select create new table and give the table name and press next.
#step 5 : Select the required conditions and press next. The data is loaded Successfully

# %%
##Pushing Data into Mongo DB
import pymongo
import pandas as pd
import json

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://New:new@cluster0.lidzegc.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#convert csv to json to uplaod dataset in mongodb

# %%
superstore.to_json("superstore.json")

# %%
pwd# checked in presnt work directory
# Out:
# 'C:\\Users\\Swapnil\\Ineuron Practice'

# %%
data=pd.read_json(r"C:\Users\Swapnil\Ineuron Practice\superstore.json")#crosscheckd data is fine

# %%
data
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
with open (r"C:\Users\Swapnil\Ineuron Practice\superstore.json") as file: data=[(json.load(file))]

# %%
database = client['superstore']#USING CONNECTIVITY WITH CLIENT DATABASE superstore created

# %%
collection = database["superstore_pandastask"]#table pandastask created

# %%
print(database)
# Out:
# Database(MongoClient(host=['ac-bkwo2y7-shard-00-02.lidzegc.mongodb.net:27017', 'ac-bkwo2y7-shard-00-01.lidzegc.mongodb.net:27017', 'ac-bkwo2y7-shard-00-00.lidzegc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-6btsqa-shard-0', tls=True), 'superstore')

# %%
collection.insert_many(data)

# %%
#now we can see database superstore in mongodb ith superstore dataset

# %%
#SOLUTION 2 Find out how return that we have recived and with a product id

# %%
superstore.head(1)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88            0.5            2
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#     Region State or Province     City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois  Addison        60101 2012-05-28 2012-05-30
#
#   Profit  Quantity ordered new Sales Order ID
# 0   1.32                     2   5.9    88525
#
# [1 rows x 24 columns]

# %%
#check excel file ,u will find returned details in sheet 2
pd.read_excel(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\INeuron_pandas data sets\Superstore_USA.xlsx",sheet_name="Returns")
#stored in in returns
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
returns=pd.read_excel(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\INeuron_pandas data sets\Superstore_USA.xlsx",sheet_name="Returns")

# %%
returns
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
superstore
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#Merge to differnt datasets

# %%
superstore_returns=pd.merge(superstore, returns)# we have merged superstore and returns

# %%
superstore_returns
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
#to check whether the both datasets are merged
superstore_returns.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %%
superstore_returns[superstore_returns.Status=="Returned"]
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
len(superstore_returns[superstore_returns.Status=="Returned"]["Order ID"])#There are total 98 orders which were returned
#In the question, Product ID is mentioned which is not available, So I have given the order ID instead.
# Out:
# 98

# %%
SOLUTION 3#try  to join order and return data both in sql and pandas

# %%
#In pandas
pd.merge(superstore,returns)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
##Join in sql
#select * from returns_done INNER JOIN orders ON orders.OrderID=returns_done.orderID;

# %%
#SOLUTION 5:Try to find out how many unique customer that we have

# %%
superstore.head(1)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88            0.5            2
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#     Region State or Province     City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois  Addison        60101 2012-05-28 2012-05-30
#
#   Profit  Quantity ordered new Sales Order ID
# 0   1.32                     2   5.9    88525
#
# [1 rows x 24 columns]

# %%
superstore["Customer Name"].unique()
# Out:
# array(['Janice Fletcher', 'Bonnie Potter', 'Ronnie Proctor', ...,
#        'Florence Gold', 'Frederick Cole', 'Tammy Buckley'], dtype=object)

# %%
superstore["Customer Name"].value_counts()
# Out:
# Louis Parrish            27
# Jenny Gold               26
# Leigh Burnette Hurley    22
# Sean N Boyer             22
# Andrew Gonzalez          21
#                          ..
# Kent Hoover               1
# Ruby Booth                1
# Bill Hudson               1
# Angela Wooten             1
# Janice Fletcher           1
# Name: Customer Name, Length: 2703, dtype: int64

# %%
len(superstore["Customer Name"].value_counts())
# Out:
# 2703

# %%
#SOLUTION 6)try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
superstore.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#check excel file ,u will find returned details in sheet 3
pd.read_excel(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\INeuron_pandas data sets\Superstore_USA.xlsx",sheet_name="Users")
managers=pd.read_excel(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\INeuron_pandas data sets\Superstore_USA.xlsx",sheet_name="Users")

# %%
managers
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#SOLUTION 7 find out how many different differnet shipement mode that we have and what is a percentage usablity of
#all the shipment mode with respect to dataset

# %%
superstore.head(1)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88            0.5            2
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#     Region State or Province     City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois  Addison        60101 2012-05-28 2012-05-30
#
#   Profit  Quantity ordered new Sales Order ID
# 0   1.32                     2   5.9    88525
#
# [1 rows x 24 columns]

# %%
superstore["Ship Mode"].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
superstore["Ship Mode"].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
total=superstore["Ship Mode"].count()

# %%
total
# Out:
# 9426

# %%
superstore["Ship Mode"].value_counts()/total*100 ##percentage usablity of all the shipment mode with respect to dataset
# Out:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship Mode, dtype: float64

# %%
#SOLUTION 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
superstore["difference_date"] =  superstore['Ship Date'] - superstore['Order Date']

# %%
superstore["difference_date"]
# Out:
# 0      2 days
# 1      1 days
# 2      1 days
# 3      1 days
# 4      0 days
#         ...
# 9421   1 days
# 9422   0 days
# 9423   2 days
# 9424   3 days
# 9425   2 days
# Name: difference_date, Length: 9426, dtype: timedelta64[ns]

# %%
#SOLUTION 9:based on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
superstore[(superstore['difference_date'].dt.components['days']>10)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %%
#SOLUTION 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and 
#find out that region manager as well

# %%
superstore.head(1)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88            0.5            2
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#   State or Province     City Postal Code  Order Date  Ship Date Profit  \
# 0          Illinois  Addison       60101  2012-05-28 2012-05-30   1.32
#
#   Quantity ordered new  Sales Order ID difference_date
# 0                    2    5.9    88525          2 days
#
# [1 rows x 25 columns]

# %%
all_data = pd.concat([superstore,returns])

# %%
all_data[(all_data['difference_date'].dt.components['days']>15)]
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 643   18246.0       Critical      0.05       11.09           5.25
# 1678  20703.0  Not Specified      0.07      130.98          30.00
# 1680  20705.0  Not Specified      0.08      115.99           4.23
# 1697   2703.0  Not Specified      0.07      130.98          30.00
# 1699   2705.0  Not Specified      0.08      115.99           4.23
# 2515  18060.0            Low      0.02        2.21           1.00
# 5673  19005.0            Low      0.06       65.99           2.50
# 5859  24392.0            Low      0.05       29.89           1.99
# 5881  21257.0            Low      0.05        7.99           5.03
# 8607  26351.0         Medium      0.00        8.32           2.38
# 8609  26350.0         Medium      0.07      180.98          55.24
# 8610  26352.0         Medium      0.06        4.20           2.26
# 8973  20750.0            Low      0.06      125.99           8.08
# ...

# %%
#SOLUTION #11. Group by region and find out which region is most profitable 
superstore.groupby(['Region'])['Profit'].count()
# Out:
# Region
# Central    2899
# East       2289
# South      1954
# West       2284
# Name: Profit, dtype: int64

# %%
superstore.groupby(['Region'])['Profit'].count().max()
# Out:
# 2899

# %%
#SOLUTION #12. Try to find out overall in which country we are giving more discount 
[superstore[superstore['Discount']>0.1]['Region']] #In central region, we are giving the most discounts.
# Out:
# [5990    Central
#  5991    Central
#  6000    Central
#  8649    Central
#  8661    Central
#  Name: Region, dtype: object]

# %%
#SOLUTION #13. Give me a list of unique postal code 
superstore['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
#SOLUTION #14 . which customer segement is more profitable find it out . 
superstore.groupby(['Customer Segment'])['Profit'].aggregate('count') #The corporate Customer segment is more profitable than others
# Out:
# Customer Segment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
superstore.groupby(['Customer Segment'])['Profit'].count()
# Out:
# Customer Segment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
#SOLUTION #15. try to find out the 10th most loss making product catagory . 
superstore[superstore['Profit']<0].reset_index().sort_values('Profit', ascending = True).head(10)
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 2291   4659   18306         Medium      0.08      175.99           4.99
# 2121   4338   20972            Low      0.01       24.95           2.99
# 3811   7800   23213            Low      0.09     6783.02          24.49
# 2381   4844   21284       Critical      0.04      880.98          44.55
# 2660   5402   24076         Medium      0.04     6783.02          24.49
# 2664   5409   22942           High      0.05     3502.14           8.73
# 3771   7725   21048  Not Specified      0.06     6783.02          24.49
# 1061   2191   21575  Not Specified      0.05     3499.99          24.49
# 1977   4068   21917           High      0.06     3502.14           8.73
# 2387   4857   24251           High      0.05     3502.14           8.73
#
#       Customer ID         Customer Name       Ship Mode Customer Segment  ...  \
# 2291         1738          Dean Solomon     Regular Air        Corporate  ...
# ...

# %%
#SOLUTION #16. Try to find out 10 top  product with highest margins 
superstore.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object
